# %% [raw]
# First thoughts:

# %% [raw]
# (0) Data:
#     -which way to deal w/ data? external library, dictionaries, ...
#         -pandas?
#
# (1) impact factors:
#     a. age
#     b. admission deposit
#     c. severity of illness
#     d. location of hospital
#     e. ward type
#     f. hospital type
# (2) hypothesis/assumptions
# (3) correlation of impact factors on length of stay:
#     a. visualize
#     b. compute correlation r
# (4) make predictive model/algorithm based upon the previous parameters
# (5) final report/conclusion
# (6) presentation
#
# add
# add 2

# %% [markdown]
# TODOS:
#     Seva:
#     Jannis:
#     Consti:
#     Sherry:
#     Stan:
#
#
#
# first todos:
#     data loading
#     create first visualisations: scatter plots
#     impact of each factor

# %% [raw]
# from Consti:
# To Do:
# - for stay & Age map group to number such that it can be used instead of a string
# - map the graphs to each other: does available bed influence the stay etc
# - what is a hospital type code for example
# '''
