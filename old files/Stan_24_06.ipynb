# %%
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib
# %pip install scipy
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.18.0)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from scipy) (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('../Topic3_healthcare_analytics_dataset.csv') # data frame impot

def get_unique_values(df, column_name=None):
   # func for unique values in a column or all columns
    if column_name:
        unique_vals = df[column_name].unique() # using pandas inherent unique function 
        print(f"--- Unique values in '{column_name}' ({len(unique_vals)} total) ---")
        return unique_vals
    else:
        unique_dict = {}
        print("--- Unique values for ALL columns ---")
        for col in df.columns:
            unique_dict[col] = df[col].unique()
            print(f"{col}: {len(unique_dict[col])} unique values")
        return unique_dict
print(unique_dict := get_unique_values(df)) # print unique values for all columns
# Out:
# --- Unique values for ALL columns ---
# case_id: 313793 unique values
# Hospital_code: 32 unique values
# Hospital_type_code: 7 unique values
# City_Code_Hospital: 11 unique values
# Hospital_region_code: 3 unique values
# Available Extra Rooms in Hospital: 18 unique values
# Department: 5 unique values
# Ward_Type: 6 unique values
# Ward_Facility_Code: 6 unique values
# Bed Grade: 4 unique values
# patientid: 90344 unique values
# City_Code_Patient: 37 unique values
# Type of Admission: 3 unique values
# Severity of Illness: 3 unique values
# Visitors with Patient: 28 unique values
# Age: 10 unique values
# Admission_Deposit: 7283 unique values
# Stay: 11 unique values
# {'case_id': array([     1,      2,      3, ..., 313791, 313792, 313793],
#       shape=(313793,)), 'Hospital_code': array([ 8,  2, 10, 26, 23, 32,  1, 22, 16,  9,  6, 29, 12,  3, 21, 28, 27,
#        19,  5, 14, 13, 31, 24, 17, 25, 15, 11, 30, 18,  4,  7, 20]), 'Hospital_type_code': <StringArray>
# ['c', 'e', 'b', 'a', 'f', 'd', 'g']
# Length: 7, dtype: str, 'City_Code_Hospital': array([ 3,  5,  1,  2,  6,  9, 10,  4, 11,  7, 13]), 'Hospital_region_code': <StringArray>
# ['Z', 'X', 'Y']
# Length: 3, dtype: str, 'Available Extra Rooms in Hospital': array([ 3,  2,  1,  4,  6,  5,  7,  8,  9, 10, 12,  0, 11, 20, 14, 21, 13,
#        24]), 'Department': <StringArray>
# ['radiotherapy', 'anesthesia', 'gynecology', 'TB & Chest disease', 'surgery']
# Length: 5, dtype: str, 'Ward_Type': <StringArray>
# ['R', 'S', 'Q', 'P', 'T', 'U']
# Length: 6, dtype: str, 'Ward_Facility_Code': <StringArray>
# ['F', 'E', 'D', 'B', 'A', 'C']
# Length: 6, dtype: str, 'Bed Grade': array([2., 3., 4., 1.]), 'patientid': array([ 31397,  63418,   8088, ..., 125235,  91081,  21641],
#       shape=(90344,)), 'City_Code_Patient': array([ 7.,  8.,  2.,  5.,  6.,  3.,  4.,  1.,  9., 14., 25., 15., 12.,
#        10., 28., 24., 23., 20., 11., 13., 21., 18., 16., 26., 27., 22.,
#        19., 31., 34., 32., 30., 29., 37., 33., 35., 36., 38.]), 'Type of Admission': <StringArray>
# ['Emergency', 'Trauma', 'Urgent']
# Length: 3, dtype: str, 'Severity of Illness': <StringArray>
# ['Extreme', 'Moderate', 'Minor']
# Length: 3, dtype: str, 'Visitors with Patient': array([ 2,  4,  3,  8,  6,  7, 13,  5,  1, 10, 15, 11, 12,  9, 24, 16, 14,
#        20,  0, 19, 18, 17, 23, 21, 32, 30, 22, 25]), 'Age': <StringArray>
# [ '51-60',  '71-80',  '31-40',  '41-50',  '81-90',  '61-70',  '21-30',
#   '11-20',   '0-10', '91-100']
# Length: 10, dtype: str, 'Admission_Deposit': array([4911., 5954., 4745., ..., 1937., 9439., 2349.], shape=(7283,)), 'Stay': <StringArray>
# [              '0-10',              '41-50',              '31-40',
#               '11-20',              '51-60',              '21-30',
#               '71-80', 'More than 100 Days',              '81-90',
#               '61-70',             '91-100']
# Length: 11, dtype: str}

# %%
Citycodes = get_unique_values(df, 'City_Code_Hospital')
print(Citycodes)
# Out:
# --- Unique values in 'City_Code_Hospital' (11 total) ---
# [ 3  5  1  2  6  9 10  4 11  7 13]

# %%
import pandas as pd

# all to see los and age corrlealtion 

# use ranks to turn intervals into usable numbers for corrleation 
stay_mapping = {
    '0-10': 1, '11-20': 2, '21-30': 3, '31-40': 4, 
    '51-60': 6, '41-50': 5, '71-80': 8, '61-70': 7, 
    '81-90': 9, '91-100': 10, 'More than 100 Days': 11
}

age_mapping = {
    '0-10': 1, '11-20': 2, '21-30': 3, '31-40': 4, 
    '41-50': 5, '51-60': 6, '61-70': 7, '71-80': 8, 
    '81-90': 9, '91-100': 10
}

# create map to rank the stay and age intervals
df['Stay_Ranked'] = df['Stay'].map(stay_mapping)
df['Age_Ranked'] = df['Age'].map(age_mapping)

# Calculate the Spearman Correlation
correlation = df['Stay_Ranked'].corr(df['Age_Ranked'], method='spearman')

print(f"The Spearman correlation between Age and Length of Stay is: {correlation:.4f}")
# Out:
# The Spearman correlation between Age and Length of Stay is: 0.0900

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# order for later grpah
los_order = [
    '0-10', '11-20', '21-30', '31-40', '41-50', 
    '51-60', '61-70', '71-80', '81-90', '91-100', 
    '>100'
]


# force stat into categorical with our custom order
df['Stay'] = pd.Categorical(df['Stay'], categories=los_order, ordered=True)

# 4. value counts function gets the number of patients in each LOS category
stay_counts = df['Stay'].value_counts().sort_index()
palette = sns.color_palette("Reds", n_colors=5)
colors = plt.cm.Reds(np.linspace(0.85, 0.35, len(stay_counts)))
print(stay_counts)

# make plot look readable
plt.figure(figsize=(5, 8)) 
sns.barplot(y=stay_counts.index, x=stay_counts.values, palette=colors)
plt.title('Distribution of Patient LOS', fontsize=14, fontweight='bold')
plt.ylabel('Length of Stay (Interval in Days)', fontsize=14)
plt.xlabel('Number of Patients', fontsize=14)
plt.xticks(rotation=45, ha='right') 

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Stay
# 0-10      23250
# 11-20     77095
# 21-30     86316
# 31-40     54312
# 41-50     11541
# 51-60     34463
# 61-70      2698
# 71-80     10096
# 81-90      4761
# 91-100     2713
# >100          0
# Name: count, dtype: int64
# /tmp/ipykernel_16690/1742792637.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=stay_counts.index, x=stay_counts.values, palette=colors)
# /tmp/ipykernel_16690/1742792637.py:24: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(y=stay_counts.index, x=stay_counts.values, palette=colors)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# age order for later graph
age_order = [
    '0-10', '11-20', '21-30', '31-40', '41-50', 
    '51-60', '61-70', '71-80', '81-90', '91-100'
]



# if we change to categorical type we get the correct order in the graph
df['Age'] = pd.Categorical(df['Age'], categories=age_order, ordered=True)

# same as above counting function for age
age_counts = df['Age'].value_counts().sort_index()

# plot aestichcs for age distribution
plt.figure(figsize=(10, 6)) 
sns.barplot(x=age_counts.index, y=age_counts.values, palette="magma")

plt.title('Distribution of Patient Ages', fontsize=16, fontweight='bold')
plt.xlabel('Age Group (Interval in Years)', fontsize=14)
plt.ylabel('Number of Patients', fontsize=14)

plt.xticks(rotation=45, ha='right') 

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16690/3226557115.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_counts.index, y=age_counts.values, palette="magma")

# %%
# dont integrate used prevous func for testing 
RegionCodes = get_unique_values(df, 'Hospital_region_code')
print(RegionCodes)
department = get_unique_values(df, 'Department')
print(department)
CityCodesPatient = get_unique_values(df, 'City_Code_Patient')
print(CityCodesPatient)
City_Code_Hospital=get_unique_values(df, 'City_Code_Hospital')
print(City_Code_Hospital)
type_of_admission = get_unique_values(df, 'Type of Admission')
print(type_of_admission)

Ward_Facility_Code = get_unique_values(df, 'Ward_Facility_Code')
print(Ward_Facility_Code)
Stay = get_unique_values(df, 'Stay')
print(Stay)
age = get_unique_values(df, 'Age')
print(age)
severity_of_illness = get_unique_values(df, 'Severity of Illness')
print(severity_of_illness)
vistories = get_unique_values(df, 'Visitors with Patient')
print(vistories)
admission_deposit = get_unique_values(df, 'Admission_Deposit')
print(admission_deposit)
type_of_admission = get_unique_values(df, 'Type of Admission')
print(type_of_admission)
# Out:
# --- Unique values in 'Hospital_region_code' (3 total) ---
# <StringArray>
# ['Z', 'X', 'Y']
# Length: 3, dtype: str
# --- Unique values in 'Department' (5 total) ---
# <StringArray>
# ['radiotherapy', 'anesthesia', 'gynecology', 'TB & Chest disease', 'surgery']
# Length: 5, dtype: str
# --- Unique values in 'City_Code_Patient' (37 total) ---
# [ 7.  8.  2.  5.  6.  3.  4.  1.  9. 14. 25. 15. 12. 10. 28. 24. 23. 20.
#  11. 13. 21. 18. 16. 26. 27. 22. 19. 31. 34. 32. 30. 29. 37. 33. 35. 36.
#  38.]
# --- Unique values in 'City_Code_Hospital' (11 total) ---
# [ 3  5  1  2  6  9 10  4 11  7 13]
# --- Unique values in 'Type of Admission' (3 total) ---
# <StringArray>
# ['Emergency', 'Trauma', 'Urgent']
# Length: 3, dtype: str
# --- Unique values in 'Ward_Facility_Code' (6 total) ---
# <StringArray>
# ['F', 'E', 'D', 'B', 'A', 'C']
# Length: 6, dtype: str
# --- Unique values in 'Stay' (11 total) ---
# ['0-10', '41-50', '31-40', '11-20', '51-60', ..., '71-80', 'More than 100 Days', '81-90', '61-70', '91-100']
# Length: 11
# Categories (11, str): ['0-10' < '11-20' < '21-30' < '31-40' ... '71-80' < '81-90' < '91-100' < 'More than 100 Days']
# --- Unique values in 'Age' (10 total) ---
# ['51-60', '71-80', '31-40', '41-50', '81-90', '61-70', '21-30', '11-20', '0-10', '91-100']
# Categories (10, str): ['0-10' < '11-20' < '21-30' < '31-40' ... '61-70' < '71-80' < '81-90' < '91-100']
# --- Unique values in 'Severity of Illness' (3 total) ---
# <StringArray>
# ['Extreme', 'Moderate', 'Minor']
# Length: 3, dtype: str
# --- Unique values in 'Visitors with Patient' (28 total) ---
# [ 2  4  3  8  6  7 13  5  1 10 15 11 12  9 24 16 14 20  0 19 18 17 23 21
#  32 30 22 25]
# --- Unique values in 'Admission_Deposit' (7283 total) ---
# [4911. 5954. 4745. ... 1937. 9439. 2349.]
# --- Unique values in 'Type of Admission' (3 total) ---
# <StringArray>
# ['Emergency', 'Trauma', 'Urgent']
# Length: 3, dtype: str

# %%
age = get_unique_values(df, 'Age')
print(age)
# Out:
# --- Unique values in 'Age' (10 total) ---
# ['51-60', '71-80', '31-40', '41-50', '81-90', '61-70', '21-30', '11-20', '0-10', '91-100']
# Categories (10, str): ['0-10' < '11-20' < '21-30' < '31-40' ... '61-70' < '71-80' < '81-90' < '91-100']

# %%
import pandas as pd
# functions for unique hospital counts per city
def count_unique_hospitals_per_city(df, city_col='City_Code_Hospital', hospital_col='Hospital_code'):
   # main body first group by city  code of hospital and  counts unique hostpital codes in each city code bin
    grouped_df = df.groupby(city_col)[hospital_col].nunique().reset_index()
    
    # rename for clarity
    grouped_df.rename(columns={hospital_col: 'Unique_Hospital_Count'}, inplace=True)
    
    # sort desecnding order for easier reading
    grouped_df = grouped_df.sort_values(by='Unique_Hospital_Count', ascending=False).reset_index(drop=True)
    
    return grouped_df
print(count_unique_hospitals_per_city(df))

#
# Out:
#     City_Code_Hospital  Unique_Hospital_Count
# 0                    1                      6
# 1                    3                      6
# 2                    5                      4
# 3                    2                      3
# 4                    4                      3
# 5                    9                      3
# 6                    6                      2
# 7                    7                      2
# 8                   10                      1
# 9                   11                      1
# 10                  13                      1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# this code plots diffrent wards'  stats such as median and std deviation of length of stay
ward_col = 'Department' 


# simplify the intervals into a midpoint which kinda hurts accuracy but is necessary for statistical analysis
stay_midpoints = {
    '0-10': 5.0, '11-20': 15.5, '21-30': 25.5, '31-40': 35.5, 
    '41-50': 45.5, '51-60': 55.5, '61-70': 65.5, '71-80': 75.5, 
    '81-90': 85.5, '91-100': 95.5, 'more than 100 days': 110.0 
}
df['Stay_Numeric'] = df['Stay'].map(stay_midpoints) # make a map 

# focus on existing wards of interest for analysis
wards_of_interest = ['gynecology', 'tb & chest disease', 'radiotherapy', 'surgery', 'anesthesia']
analysis_df = df[df[ward_col].isin(wards_of_interest)].dropna(subset=['Stay_Numeric'])

print("--- Clinical Assumptions Check: Statistics ---")
# ward stats calcuation by  aggretaing function and getting  median los STD  and count
ward_stats = analysis_df.groupby(ward_col)['Stay_Numeric'].agg(['count', 'median', 'std']).round(2)
ward_stats = ward_stats.rename(columns={'count': 'Total Patients', 'median': 'Median LOS', 'std': 'Std Deviation (Variance)'})

# sort assceding by std 
ward_stats = ward_stats.sort_values(by='Std Deviation (Variance)', ascending=True)
print(ward_stats)



plt.figure(figsize=(12, 7))

#  nice violin plot to better show how distrubtion works + plot aesthetics
sns.violinplot(
    data=analysis_df, 
    x=ward_col, 
    y='Stay_Numeric', 
    palette='Set2',
    inner='quartile' 
)

plt.title('Distribution of Length of Stay by Hospital Ward', fontsize=16, fontweight='bold')
plt.xlabel('Hospital Department', fontsize=14)
plt.ylabel('Length of Stay (Midpoint in Days)', fontsize=14)

plt.xticks(labels=[text.title() for text in wards_of_interest], fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# --- Clinical Assumptions Check: Statistics ---
#               Total Patients  Median LOS  Std Deviation (Variance)
# Department
# anesthesia             28589        25.5                     17.08
# gynecology            240993        25.5                     18.99
# radiotherapy           27228        25.5                     19.74
# surgery                 1099        25.5                     21.43
# /tmp/ipykernel_16690/1505092072.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 48
#      45 plt.xlabel('Hospital Department', fontsize=14)
#      46 plt.ylabel('Length of Stay (Midpoint in Days)', fontsize=14)
# ---> 48 plt.xticks(labels=[text.title() for text in wards_of_interest], fontsize=12)
#      49 plt.grid(axis='y', linestyle='--', alpha=0.7)
#      51 plt.tight_layout()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/matplotlib/pyplot.py:2384, in xticks(ticks, labels, minor, **kwargs)
#    2382     locs = ax.get_xticks(minor=minor)
#    2383     if labels is not None:
# -> 2384         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2385                         "without setting 'ticks'")
#    2386 else:
#    2387     locs = ax.set_xticks(ticks, minor=minor)
#
# TypeError: xticks(): Parameter 'labels' can't be set without setting 'ticks'

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
# we use stay numeric from the preovus cell 
patient_col = 'patientid' 
# goruping the same cases of the patient and using agg func we get the  total  visitcs and mean los 
patient_df = df.groupby(patient_col).agg(
    Total_Visits=('Stay_Numeric', 'count'),
    Average_LOS=('Stay_Numeric', 'mean')
).reset_index()


# statisctical ananlysis  
print("--- Patient Chronicity Analysis ---")

#  fix from prevous version where same  value in variance crashed the algotithm 
visits_variance = patient_df['Total_Visits'].nunique()
los_variance = patient_df['Average_LOS'].nunique()

if visits_variance <= 1 or los_variance <= 1:
    print("ERROR: One of the columns lacks variation (e.g., all patients have exactly 1 visit).")
    print("Spearman correlation is mathematically impossible with this specific dataset.")
else:
    corr, p_value = stats.spearmanr(patient_df['Total_Visits'], patient_df['Average_LOS'])
    #  get the corrlation of total visits and  average los and p value (value that calutaes  the s
    # statistacal signiface of this correlation)
    print(f"Spearman Correlation (Visits vs Avg LOS): {corr:.4f}")
    print(f"P-value: {p_value:.4f}")
    #  conclusion calcualtion 
    if p_value < 0.05:
        if corr > 0:
            print("Conclusion: Statistically significant POSITIVE trend. Frequent patients stay longer.")
        elif corr < 0:
            print("Conclusion: Statistically significant NEGATIVE trend. Frequent patients have shorter stays.")
    else:
        print("Conclusion: No statistically significant relationship found.")


# Cap extreme outliers into a single "5+" category for a cleaner X-axis
patient_df['Visit_Category'] = patient_df['Total_Visits'].apply(
    lambda x: str(x) if x < 5 else '5+'
)

# order for for graph
visit_order = ['1', '2', '3', '4', '5+']
patient_df['Visit_Category'] = pd.Categorical(patient_df['Visit_Category'], categories=visit_order, ordered=True)

plt.figure(figsize=(10, 6))

# Draw the point plot
sns.pointplot(
    data=patient_df, 
    x='Visit_Category', 
    y='Average_LOS', 
    color='crimson',
    capsize=0.1 
)
# we center the line to avoid falsely zooming in the data 
max_los = patient_df['Average_LOS'].max()
plt.ylim(0, max_los * 1.1)

plt.title('Impact of Patient Chronicity on Average Length of Stay', fontsize=16, fontweight='bold')
plt.xlabel('Total Number of Hospital Admissions per Patient', fontsize=14)
plt.ylabel('Average Length of Stay (Days)', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# --- Patient Chronicity Analysis ---
# Spearman Correlation (Visits vs Avg LOS): nan
# P-value: nan
# Conclusion: No statistically significant relationship found.
# C:\Users\sss\AppData\Local\Temp\ipykernel_1988\2533880295.py:52: Pandas4Warning: Constructing a Categorical with a dtype and values containing non-null entries not in that dtype's categories is deprecated and will raise in a future version.
#   patient_df['Visit_Category'] = pd.Categorical(patient_df['Visit_Category'], categories=visit_order, ordered=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


patient_col = 'patientid' 

visits_per_patient = df.groupby(patient_col).size().reset_index(name='Total_Visits')
#group  the same patient cases 
visit_distribution = visits_per_patient['Total_Visits'].value_counts().reset_index()
# count  how many unique patients share the same  number of vists 
visit_distribution.columns = ['Number_of_Visits', 'Patient_Count']

visit_distribution = visit_distribution.sort_values(by='Number_of_Visits').reset_index(drop=True)

print("--- Distribution of Patient Visits ---")
print(visit_distribution.head(10)) # Print the first 10 rows to see the bulk of the data


plt.figure(figsize=(10, 6))

# 
plot_data = visit_distribution.head(10)

sns.barplot(
    data=plot_data, 
    x='Number_of_Visits', 
    y='Patient_Count', 
    palette='Blues_r' # Using a blue gradient to differentiate from previous charts
)

plt.title('How Many Patients Had a Specific Number of Visits?', fontsize=16, fontweight='bold')
plt.xlabel('Number of Hospital Visits', fontsize=14)
plt.ylabel('Total Unique Patients', fontsize=14)
# format the commas for readability
plt.gca().yaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter('{x:,.0f}'))

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# --- Distribution of Patient Visits ---
#    Number_of_Visits  Patient_Count
# 0                 1          19811
# 1                 2          18090
# 2                 3          15411
# 3                 4          12179
# 4                 5           9147
# 5                 6           6221
# 6                 7           4011
# 7                 8           2324
# 8                 9           1381
# 9                10            752
# /tmp/ipykernel_16690/1311488916.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
