# %% [raw]
# First thoughts:

# %% [raw]
# (0) Data:
#
# (1) impact factors:
#     a. age
#     b. admission deposit
#     c. severity of illness
#     d. location of hospital
#     e. ward type
#     f. hospital type
# (2) hypothesis/assumptions
# (3) correlation of impact factors on length of stay:
#     a. visualize
#     b. compute correlation r
# (4) make predictive model/algorithm based upon the previous parameters
# (5) final report/conclusion
# (6) presentation

# %% [markdown]
# TODOS:
#     Seva:
#     Jannis:
#     Consti:
#     Sherry:
#     Stan:
